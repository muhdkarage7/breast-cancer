# %%
# !pip install weave google-generativeai

# %%
import os
import random
import json
import datetime
from typing import TypedDict, Optional
import enum
import google.generativeai as genai
import time

# %%
# import weave
# import wandb
from dotenv import load_dotenv

# %%
load_dotenv()
genai.configure(api_key=os.environ.get("GEMINI_API_KEY"))
# wandb.login(key=os.environ.get("WANDB_API_KEY"))
# weave.init(project_name="expense-bot")

# %%
def upload_to_gemini(path, mime_type=None):
  """Uploads the given file to Gemini.

  See https://ai.google.dev/gemini-api/docs/prompting_with_media
  """
  file = genai.upload_file(path, mime_type=mime_type)
  print(f"Uploaded file '{file.display_name}' as: {file.uri}")
  return file

# %%
# Function to read already processed images from output files
def get_processed_images(*output_files):
    """Reads the output files and returns a set of processed image names."""
    processed_images = set()
    for output_file in output_files:
        if os.path.exists(output_file):
            with open(output_file, 'r') as f:
                for line in f:
                    try:
                        data = json.loads(line)
                        image_name = data.get('image')
                        if image_name:
                            processed_images.add(image_name)
                    except json.JSONDecodeError:
                        continue
    return processed_images

def process_receipts(
    directory,
    num_images=None,
    validation_split=0.2,
    output_train_file="train_output.jsonl",
    output_validation_file="validation_output.jsonl"
):
    """Processes images in the directory, extracting information from receipts.

    Args:
        directory (str): Path to the directory containing receipt images.
        num_images (int, optional): Number of images to process. If None, process all images.
        validation_split (float): Proportion of data to use for validation (e.g., 0.2 for 20%).
        output_train_file (str): Filename for training data output.
        output_validation_file (str): Filename for validation data output.
    """
    # List all files in the directory
    files = os.listdir(directory)
    # Filter to only image files (e.g., .jpeg, .jpg, .png)
    image_files = [f for f in files if f.lower().endswith(('.jpeg', '.jpg', '.png'))]

    # If num_images is specified, limit the number of images
    if num_images is not None:
        image_files = image_files[:num_images]

    # Shuffle the image files
    random.shuffle(image_files)

    # Split into training and validation sets
    split_index = int(len(image_files) * (1 - validation_split))
    train_images = image_files[:split_index]
    validation_images = image_files[split_index:]

    print(f"Total images: {len(image_files)}")
    print(f"Training images: {len(train_images)}")
    print(f"Validation images: {len(validation_images)}")

    # Get today's date
    today = datetime.date.today()

    # Define the Categories and Subcategories
    expense_categories = [
        {
            "category": "Office and Administrative",
            "subcategories": [
                "Stationery and Printing",
                "Postage and Courier",
                "Telephone and Internet",
                "Office Rent",
                "Utilities (Electricity, Gas, Water)",
                "Office Insurance",
                "Office Maintenance and Repairs",
                "Office Equipment (under £1,000)",
                "Software Subscriptions",
                "Domain and Hosting Fees"
            ]
        },
        {
            "category": "Employee Costs",
            "subcategories": [
                "Salaries and Wages",
                "Employer's National Insurance Contributions",
                "Pension Contributions",
                "Staff Training",
                "Employee Benefits",
                "Recruitment Costs",
                "Staff Uniforms",
                "Staff Entertainment"
            ]
        },
        {
            "category": "Travel and Transportation",
            "subcategories": [
                "Vehicle Fuel",
                "Vehicle Insurance",
                "Vehicle Maintenance and Repairs",
                "Vehicle Road Tax",
                "Parking Fees",
                "Public Transportation Fares",
                "Accommodation for Business Trips",
                "Meals During Business Travel",
                "Mileage Allowance"
            ]
        },
        {
            "category": "Professional Services",
            "subcategories": [
                "Accountancy Fees",
                "Legal Fees",
                "Consulting Fees",
                "IT Support Services"
            ]
        },
        {
            "category": "Marketing and Advertising",
            "subcategories": [
                "Advertising Costs",
                "Marketing Materials",
                "Website Development and Maintenance",
                "Social Media Marketing",
                "Trade Show Expenses",
                "Promotional Items"
            ]
        },
        {
            "category": "Financial Expenses",
            "subcategories": [
                "Bank Charges",
                "Credit Card Fees",
                "Loan Interest",
                "Merchant Fees",
                "Bad Debts"
            ]
        },
        {
            "category": "Insurance",
            "subcategories": [
                "Professional Indemnity Insurance",
                "Public Liability Insurance",
                "Employers' Liability Insurance",
                "Contents Insurance"
            ]
        },
        {
            "category": "Subscriptions and Memberships",
            "subcategories": [
                "Professional Body Memberships",
                "Trade Association Fees",
                "Magazine and Journal Subscriptions"
            ]
        },
        {
            "category": "Research and Development",
            "subcategories": [
                "R&D Materials",
                "R&D Equipment",
                "R&D Consulting Fees"
            ]
        },
        {
            "category": "Depreciation and Capital Allowances",
            "subcategories": [
                "Depreciation of Assets",
                "Annual Investment Allowance",
                "Writing Down Allowance"
            ]
        },
        {
            "category": "Rent and Rates",
            "subcategories": [
                "Business Premises Rent",
                "Business Rates"
            ]
        },
        {
            "category": "Repairs and Maintenance",
            "subcategories": [
                "Building Repairs",
                "Equipment Maintenance"
            ]
        },
        {
            "category": "Cost of Goods Sold",
            "subcategories": [
                "Raw Materials",
                "Direct Labor",
                "Manufacturing Overheads"
            ]
        },
        {
            "category": "Charitable Donations",
            "subcategories": [
                "Donations to Registered Charities"
            ]
        },
        {
            "category": "Miscellaneous Expenses",
            "subcategories": [
                "Cleaning Services",
                "Security Services",
                "Health and Safety Expenses",
                "Waste Disposal"
            ]
        },
        {
            "category": "Home Office Expenses",
            "subcategories": [
                "Proportion of Rent or Mortgage Interest",
                "Proportion of Utilities",
                "Proportion of Council Tax",
                "Proportion of Home Insurance"
            ]
        }
    ]

    # VAT Percentages per Category
    vat_percentages = {
        "Office and Administrative": 20.0,
        "Employee Costs": 20.0,
        "Travel and Transportation": 0.0,
        "Professional Services": 20.0,
        "Marketing and Advertising": 20.0,
        "Financial Expenses": 0.0,
        "Insurance": 0.0,
        "Subscriptions and Memberships": 0.0,
        "Research and Development": 20.0,
        "Depreciation and Capital Allowances": 0.0,
        "Rent and Rates": 20.0,
        "Repairs and Maintenance": 20.0,
        "Cost of Goods Sold": 20.0,
        "Charitable Donations": 0.0,
        "Miscellaneous Expenses": 20.0,
        "Home Office Expenses": 0.0
    }

    # Define the schema using TypedDict
    class TransactionDetails(TypedDict):
        transaction_date: str  # YYYY-MM-DD format
        transaction_timestamp: str  # YYYY-MM-DD HH:MM:SS format
        amount: float  # numeric value
        currency: str  # e.g., "GBP"
        description: str
        transaction_type: str  # e.g., "Expense"
        category: str
        subcategory: str
        payment_method: str  # e.g., "Card"
        merchant: str
        transaction_id: Optional[str]  # Optional
        vat_percentage: float  # e.g., 20.0
        original_currency: Optional[str]  # If not GBP
        original_amount: Optional[float]  # If not GBP

    # Create the model with the response schema
    generation_config = genai.GenerationConfig(
        temperature=0.2,
        top_p=0.9,
        top_k=40,
        max_output_tokens=1024,
        response_mime_type="application/json",
        response_schema=TransactionDetails,
    )

    model = genai.GenerativeModel(
        model_name="gemini-1.5-pro",
        generation_config=generation_config,
    )

    # Get the set of already processed images
    processed_images = get_processed_images(output_train_file, output_validation_file)

    # Function to process a list of images and write outputs to a file
    def process_images(image_list, output_file):
        # Open the output file in append mode to avoid overwriting existing data
        with open(output_file, 'a') as f:
            for image_file in image_list:
                if image_file in processed_images:
                    print(f"Image '{image_file}' has already been processed. Skipping.")
                    continue

                image_path = os.path.join(directory, image_file)

                max_retries = 5
                retry_delay = 1  # Start with 1 second delay
                retries = 0

                while retries < max_retries:
                    try:
                        # Upload the image to Gemini
                        uploaded_file = upload_to_gemini(image_path, mime_type="image/jpeg")
                        print(f"Uploaded file '{image_file}' as: {uploaded_file.uri}")

                     # Add user input for the monthly budget and calculate the weekly budget
monthly_budget = float(input("Enter your monthly budget: "))
weekly_budget = monthly_budget / 4

# Prompt user for alert preference for market price changes
alert_for_marketprice_changes = input("Do you want alert for market price changes? (Yes/No): ").strip().lower()

# Validate and process the input
if alert_for_marketprice_changes == "yes":
    alert_preference = True
elif alert_for_marketprice_changes == "no":
    alert_preference = False
else:
    raise ValueError("Invalid input! Please enter 'Yes' or 'No'.")

print(f"Alert for market price changes: {alert_preference}")


# Update message content to include the weekly budget in the prompt
prompt = f"""Analyze this receipt image and extract transaction details.
Today's date is {today.strftime('%Y-%m-%d')}.
Select the category and subcategory from the predefined list of expense categories and subcategories.

Weekly Budget: £{weekly_budget:.2f}

Expense Categories and Subcategories:
{json.dumps(expense_categories, indent=2)}

VAT Percentages per Category:
{json.dumps(vat_percentages, indent=2)}

Important:
- Amount must be a number (not a string)
- Date must be in YYYY-MM-DD format
- Transaction timestamp must be in YYYY-MM-DD HH:MM:SS format
    - If time is not available, set time to "00:00:00"
- If currency is not GBP, provide the original amount and currency
- Include the VAT percentage based on the category as per the list above

Return the data in the JSON format specified by the response schema.
"""

                        # Prepare the message content with the prompt and weekly budget

                        message_content = [uploaded_file, prompt]

                        # Start a chat session
                        chat_session = model.start_chat()

                        # Send the message to the model
                        response = chat_session.send_message(message_content)

                        # Get the AI's response text
                        ai_response = response.text.strip()

                        # Create the JSON object for this image
                        result = {
                            "prefix": "",
                            "suffix": ai_response,  # Store the AI response as is
                            "image": image_file
                        }

                        # Write the result to the JSONL file
                        json_line = json.dumps(result)
                        f.write(json_line + '\n')

                        # Print the response
                        print(f"\nProcessed image '{image_file}':\n{json_line}\n")

                        # Add image to processed_images set
                        processed_images.add(image_file)

                        # Break out of the retry loop if successful
                        break

                    except Exception as e:
                        print(f"Error processing image '{image_file}': {e}")
                        retries += 1
                        print(f"Retrying ({retries}/{max_retries}) after {retry_delay} seconds...")
                        time.sleep(retry_delay)
                        retry_delay += 2  # Incremental backoff

                else:
                    # If max retries reached, log the failure
                    print(f"Failed to process image '{image_file}' after {max_retries} retries.")

    # Process training images
    print("\nProcessing training images...\n")
    process_images(train_images, output_train_file)
    print(f"Training data written to {output_train_file}")

    # Process validation images
    print("\nProcessing validation images...\n")
    process_images(validation_images, output_validation_file)
    print(f"Validation data written to {output_validation_file}")

# %%
def weekly_budget_alert(output_file, weekly_budget):
    """Calculates weekly expenses and alerts if the budget is exceeded."""
    from datetime import datetime, timedelta

    today = datetime.now()
    one_week_ago = today - timedelta(days=7)

    total_spent = 0
    try:
        with open(output_file, 'r') as f:
            for line in f:
                data = json.loads(line)
                transaction_date = data.get("suffix", {}).get("transaction_date", None)
                amount = data.get("suffix", {}).get("amount", 0)

                # Convert the transaction date to datetime and check if it falls within the past week
                if transaction_date:
                    transaction_date = datetime.strptime(transaction_date, "%Y-%m-%d")
                    if one_week_ago <= transaction_date <= today:
                        total_spent += amount

        print(f"Weekly Spending: £{total_spent:.2f}")
        if total_spent > weekly_budget:
            print(f" Alert: You have exceeded your weekly budget of £{weekly_budget:.2f} by £{total_spent - weekly_budget:.2f}!")
        else:
            print(f" You are within your weekly budget of £{weekly_budget:.2f}.")

    except FileNotFoundError:
        print(f"File '{output_file}' not found.")
    except json.JSONDecodeError:
        print("Error decoding JSON from the output file.")

# Example usage
weekly_budget_alert("train_output.jsonl",)

# %%
pip install beautifulsoup4 requests
from bs4 import BeautifulSoup
import requests

def monitor_market_prices(regular_items, url):
    """
    Scrapes market prices from the given URL and alerts if there are changes
    for regularly purchased items.

    Args:
        regular_items (dict): A dictionary of items and their expected prices, e.g., {"item_name": 10.0}.
        url (str): The URL of the market price page to scrape.
    """
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Simulate scraping: This needs to be adapted to the actual site's structure
        # Example: Assuming prices are in <div class="price"> elements and item names in <span class="item-name">
        market_prices = {}
        for item in soup.find_all("div", class_="item"):
            name = item.find("span", class_="item-name").text.strip()
            price = float(item.find("span", class_="price").text.strip().replace("£", ""))
            market_prices[name] = price

        # Compare scraped prices with regular items
        for item, expected_price in regular_items.items():
            current_price = market_prices.get(item)
            if current_price:
                if current_price != expected_price:
                    print(f" Price Alert: '{item}' price changed from £{expected_price:.2f} to £{current_price:.2f}.")
            else:
                print(f"'{item}' not found in the market price data.")

    except requests.RequestException as e:
        print(f"Error fetching market prices: {e}")

# Example usage
regular_items = {"Milk": 1.50, "Bread": 1.00, "Eggs": 2.00}
monitor_market_prices(regular_items, "https://example.com/market-prices")

# %%
process_receipts(
    "./Receipt.v1i.paligemma/dataset",
    # num_images=3,
    validation_split=0.2
)
# Out:
# Total images: 1193
# Training images: 954
# Validation images: 239
#
# Processing training images...
#
# Uploaded file '0036_jpg.rf.463e814e9a2a40548e9c31c8085cf785.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/bckj03q0j4q4
# Uploaded file '0036_jpg.rf.463e814e9a2a40548e9c31c8085cf785.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/bckj03q0j4q4
#
# Processed image '0036_jpg.rf.463e814e9a2a40548e9c31c8085cf785.jpg':
# {"prefix": "", "suffix": "{\"amount\": 991.7, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"Invoice from Crane Pool & Schmidt Pte Ltd\", \"merchant\": \"Crane Pool & Schmidt Pte Ltd\", \"transaction_date\": \"2022-05-15\", \"transaction_timestamp\": \"2022-05-15 00:00:00\", \"vat_percentage\": 20.0}", "image": "0036_jpg.rf.463e814e9a2a40548e9c31c8085cf785.jpg"}
#
# Uploaded file '93_jpg.rf.88f2f31c8afa52963367cc94b06225aa.jpg' as: https://generativelanguage.googleapis.com/v1beta/files
jpg' as: https://generativelanguage.googleapis.com/v1beta/files/kkiqn2xo62w4
# Uploaded file 'geek64_jpg.rf.a824555bb0a81260449406ea178c6a2b.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/kkiqn2xo62w4
#
# Processed image 'geek64_jpg.rf.a824555bb0a81260449406ea178c6a2b.jpg':
# {"prefix": "", "suffix": "{\"amount\": 867.12, \"category\": \"Food & Drink\", \"subcategory\": \"Restaurant\", \"transaction_date\": \"2024-12-01\", \"transaction_timestamp\": \"2024-12-01 00:00:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "geek64_jpg.rf.a824555bb0a81260449406ea178c6a2b.jpg"}
#
# Uploaded file '110_jpg.rf.840a5cfe34179f6dca9e1d5b863cc520.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/qy4w9rsd61t1
# Uploaded file '110_jpg.rf.840a5cfe34179f6dca9e1d5b863cc520.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/qy4w9rsd61t1
#
# Processed image '110_jpg.rf.840a5cfe34179f6dca9e1d5b863cc520.jpg':
# {"prefix": "", "suffix": "{\"amount\": 486.0, \"category\": \"Food & Drink\", \"currency\": \"INR\", \"description\": \"Khandelwal Dhaba\", \"merchant\": \"Khandelwal Dhaba\", \"transaction_date\": \"2027-07-31\", \"transaction_timestamp\": \"2027-07-31 00:00:00\", \"transaction_type\": \"Purchase\"}", "image": "110_jpg.rf.840a5cfe34179f6dca9e1d5b863cc520.jpg"}
#
# Uploaded file 'geek55_jpg.rf.b67fb97a68c75438102b3553411453f6.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/3w8aswtdidt6
# Uploaded file 'geek55_jpg.rf.b67fb97a68c75438102b3553411453f6.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/3w8aswtdidt6
#
# Processed image 'geek55_jpg.rf.b67fb97a68c75438102b3553411453f6.jpg':
# {"prefix": "", "suffix": "{\"amount\": 845.00, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"Anubhutee Peacock Blue Kurta Set with Golden Traditional Motifs\", \"merchant\": \"Myntra\", \"original_amount\": 845.00, \"original_currency\": \"INR\", \"transaction_date\": \"2020-10-20\", \"transaction_timestamp\": \"2020-10-20 00:00:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "geek55_jpg.rf.b67fb97a68c75438102b3553411453f6.jpg"}
#
# Error processing image 'geek69_jpg.rf.3e3179654abd2c8aac7cfa739934c726.jpg': 503 The service is currently unavailable.
# Retrying (1/5) after 1 seconds...
# Uploaded file 'geek69_jpg.rf.3e3179654abd2c8aac7cfa739934c726.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/js0faa761s44
# Uploaded file 'geek69_jpg.rf.3e3179654abd2c8aac7cfa739934c726.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/js0faa761s44
#
# Processed image 'geek69_jpg.rf.3e3179654abd2c8aac7cfa739934c726.jpg':
# {"prefix": "", "suffix": "{\"amount\": 482.6, \"category\": \"Food and Beverage\", \"currency\": \"INR\", \"description\": \"Zomato Food Order\", \"merchant\": \"Grillland BBQ\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"zomato\", \"subcategory\": \"Restaurant\", \"transaction_date\": \"2022-04-23\", \"transaction_id\": \"4005441110\", \"transaction_timestamp\": \"2022-04-23 02:44:00\", \"transaction_type\": \"purchase\", \"vat_percentage\": 0.0}", "image": "geek69_jpg.rf.3e3179654abd2c8aac7cfa739934c726.jpg"}
#
# Error processing image 'Screenshot 2024-11-30 at 22.03.36.png': 503 The service is currently unavailable.
# Retrying (1/5) after 1 seconds...
# Uploaded file 'Screenshot 2024-11-30 at 22.03.36.png' as: https://generativelanguage.googleapis.com/v1beta/files/kiao0z774xa8
# Uploaded file 'Screenshot 2024-11-30 at 22.03.36.png' as: https://generativelanguage.googleapis.com/v1beta/files/kiao0z774xa8
#
# Processed image 'Screenshot 2024-11-30 at 22.03.36.png':
# {"prefix": "", "suffix": "{\"amount\": 15.6, \"category\": \"Office and Administrative\", \"currency\": \"USD\", \"description\": \"One-time credit purchase\", \"merchant\": \"Anthropic\", \"original_amount\": 15.6, \"original_currency\": \"USD\", \"transaction_date\": \"2024-11-25\", \"transaction_timestamp\": \"2024-11-25 00:00:00\", \"vat_percentage\": 20.0}", "image": "Screenshot 2024-11-30 at 22.03.36.png"}
#
# Uploaded file '0016_jpg.rf.0779b06d5af5c86e99b9fd630add33cc.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/c7nzvllhigye
# Uploaded file '0016_jpg.rf.0779b06d5af5c86e99b9fd630add33cc.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/c7nzvllhigye
#
# Processed image '0016_jpg.rf.0779b06d5af5c86e99b9fd630add33cc.jpg':
# {"prefix": "", "suffix": "{\"amount\": 1486.8, \"category\": \"Office and Administrative\", \"currency\": \"USD\", \"description\": \"Carson City Publishers\", \"merchant\": \"Carson City Publishers\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"invoice\", \"subcategory\": \"Stationery and Printing\", \"transaction_date\": \"2022-06-19\", \"transaction_id\": \"INV-17651230\", \"transaction_timestamp\": \"2022-06-19 00:00:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 18.0}", "image": "0016_jpg.rf.0779b06d5af5c86e99b9fd630add33cc.jpg"}
#
# Uploaded file 'geek44_jpg.rf.f9dbd7351eeb4806809df44de036c051.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/h3q0306d2ic8
# Uploaded file 'geek44_jpg.rf.f9dbd7351eeb4806809df44de036c051.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/h3q0306d2ic8
#
# Processed image 'geek44_jpg.rf.f9dbd7351eeb4806809df44de036c051.jpg':
# {"prefix": "", "suffix": "{\"amount\": 138.0, \"category\": \"Office and Administrative\", \"currency\": \"INR\", \"description\": \"Nursery Rhymes Jumbo Picture Book-A3 Size Book with\\n31 Rhymes for Early Leamers (My Jumbo Books)\\n8184516207 (8184516207)\", \"merchant\": \"COCOBLU RETAIL LIMITED\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"Credit Card\", \"subcategory\": \"Stationery and Printing\", \"transaction_date\": \"2022-06-21\", \"transaction_id\": \"405-3682128-8275536\", \"transaction_timestamp\": \"2022-06-21 00:00:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "geek44_jpg.rf.f9dbd7351eeb4806809df44de036c051.jpg"}
#
# Uploaded file 'geek65_jpg.rf.c2120ef6970b8f422ca3ac7a9ca45ddb.jpg' as: https://generativelanguage.googleapis.com/v1beta/files
jpg' as: https://generativelanguage.googleapis.com/v1beta/files/d0dwyy7492vs
#
# Processed image '86_jpeg_jpg.rf.a6b3d633d19793b1f570cb64d3ca6314.jpg':
# {"prefix": "", "suffix": "{\"amount\": 330, \"category\": \"Travel and Transportation\", \"currency\": \"USD\", \"description\": \"Bicycle - ACME Super Rider\\nSpare Bicycle Tire\\nCycling Gloves\", \"merchant\": \"ACME BIKE SHOP\", \"payment_method\": \"Cash\", \"transaction_date\": \"2018-10-20\", \"transaction_timestamp\": \"2018-10-20 00:00:00\", \"vat_percentage\": 0.0}", "image": "86_jpeg_jpg.rf.a6b3d633d19793b1f570cb64d3ca6314.jpg"}
#
# Uploaded file '56_jpg.rf.38b032ce6ea8f0f491e79591068bc8d4.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/1t1jzug5l565
# Uploaded file '56_jpg.rf.38b032ce6ea8f0f491e79591068bc8d4.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/1t1jzug5l565
#
# Processed image '56_jpg.rf.38b032ce6ea8f0f491e79591068bc8d4.jpg':
# {"prefix": "", "suffix": "{\"amount\": 91.35, \"category\": \"Miscellaneous Expenses\", \"currency\": \"MYR\", \"description\": \"ABC FOOD CORNER\", \"merchant\": \"ABC FOOD CORNER\", \"transaction_date\": \"2015-03-22\", \"transaction_timestamp\": \"2015-03-22 12:28:24\", \"vat_percentage\": 0.0}", "image": "56_jpg.rf.38b032ce6ea8f0f491e79591068bc8d4.jpg"}
#
# Uploaded file 'geek44_jpg.rf.b8e07447549b4daf4e52cb43519ac91f.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/vfpwgzyf9ory
# Uploaded file 'geek44_jpg.rf.b8e07447549b4daf4e52cb43519ac91f.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/vfpwgzyf9ory
#
# Processed image 'geek44_jpg.rf.b8e07447549b4daf4e52cb43519ac91f.jpg':
# {"prefix": "", "suffix": "{\"amount\": 138.0, \"category\": \"Office and Administrative\", \"currency\": \"INR\", \"description\": \"Nursery Rhymes Jumbo Picture Book-A3 Size Book with\\n31 Rhymes for Early Learners (My Jumbo Books)\", \"merchant\": \"COCOBLU RETAIL LIMITED\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"Credit Card\", \"subcategory\": \"Stationery and Printing\", \"transaction_date\": \"2022-06-21\", \"transaction_id\": \"405-3682128-8275536\", \"transaction_timestamp\": \"2022-06-21 00:00:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "geek44_jpg.rf.b8e07447549b4daf4e52cb43519ac91f.jpg"}
#
# Error processing image 'geek46_jpg.rf.d8588a855ec8e0608b796b0447a3d912.jpg': 503 The service is currently unavailable.
# Retrying (1/5) after 1 seconds...
# Uploaded file 'geek46_jpg.rf.d8588a855ec8e0608b796b0447a3d912.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/yx6gjwie7owp
# Uploaded file 'geek46_jpg.rf.d8588a855ec8e0608b796b0447a3d912.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/yx6gjwie7owp
#
# Processed image 'geek46_jpg.rf.d8588a855ec8e0608b796b0447a3d912.jpg':
# {"prefix": "", "suffix": "{\"amount\": 599.0, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"TIGYWIGY Women's Satin Printed Top and Pyjama Set Pack of 1\\n(2002_Onion_Small) | BOBQBKJSBW_(2007_Onion_S)\", \"merchant\": \"amazon.in\", \"payment_method\": \"Card\", \"subcategory\": \"Raw Materials\", \"transaction_date\": \"2022-06-12\", \"transaction_id\": \"404-7039216-8485940\", \"transaction_timestamp\": \"2022-06-12 13:22:14\", \"vat_percentage\": 4.0}", "image": "geek46_jpg.rf.d8588a855ec8e0608b796b0447a3d912.jpg"}
#
# Uploaded file 'geek103_jpg.rf.fc9f5a62d0f4a6791b2d1f73c3b9bc19.jpg' as: https://generativelanguage.googleapis.com/v1beta/files
#
# Uploaded file 'geek7_jpg.rf.9782f74a44f00f4b81cc290ae202a1da.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/3wbxhul40nfm
# Uploaded file 'geek7_jpg.rf.9782f74a44f00f4b81cc290ae202a1da.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/3wbxhul40nfm
#
# Processed image 'geek7_jpg.rf.9782f74a44f00f4b81cc290ae202a1da.jpg':
# {"prefix": "", "suffix": "{\"amount\": 886.0, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"Capri set M\", \"merchant\": \"Trendy Outfits\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"credit_card\", \"subcategory\": \"Raw Materials\", \"transaction_date\": \"2023-06-27\", \"transaction_id\": \"190796710708\", \"transaction_timestamp\": \"2023-06-27 00:00:00\", \"transaction_type\": \"purchase\", \"vat_percentage\": 20.0}", "image": "geek7_jpg.rf.9782f74a44f00f4b81cc290ae202a1da.jpg"}
#
# Uploaded file '004_jpg.rf.8b256b83d97506558907b41c5c370c8b.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/5mf21ius6ewc
# Uploaded file '004_jpg.rf.8b256b83d97506558907b41c5c370c8b.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/5mf21ius6ewc
#
# Processed image '004_jpg.rf.8b256b83d97506558907b41c5c370c8b.jpg':
# {"prefix": "", "suffix": "{\"amount\": 908.6, \"category\": \"Cost of Goods Sold\", \"currency\": \"USD\", \"description\": \"Balance Due\", \"merchant\": \"Crane Pool & Schmidt Pte Ltd\", \"transaction_date\": \"2022-04-30\", \"transaction_timestamp\": \"2022-04-30 00:00:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "004_jpg.rf.8b256b83d97506558907b41c5c370c8b.jpg"}
#
# Error processing image '100_jpg.rf.2dce06a2d619b223dbd449cfcbddedae.jpg': 503 The service is currently unavailable.
# Retrying (1/5) after 1 seconds...
# Uploaded file '100_jpg.rf.2dce06a2d619b223dbd449cfcbddedae.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/6unvufcnm49w
# Uploaded file '100_jpg.rf.2dce06a2d619b223dbd449cfcbddedae.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/6unvufcnm49w
#
# Processed image '100_jpg.rf.2dce06a2d619b223dbd449cfcbddedae.jpg':
# {"prefix": "", "suffix": "{\"amount\": 660.0, \"category\": \"Food and Drink\", \"currency\": \"INR\", \"description\": \"Chandu Dhaba\", \"merchant\": \"Chandu Dhaba\", \"original_amount\": 660.0, \"original_currency\": \"INR\", \"transaction_date\": \"2018-07-08\", \"transaction_timestamp\": \"2018-07-08 21:48:00\", \"transaction_type\": \"Purchase\"}", "image": "100_jpg.rf.2dce06a2d619b223dbd449cfcbddedae.jpg"}
#
# Error processing image '0049_jpg.rf.60277a51b0beb8fdd8318fcdfce3d8aa.jpg': 503 The service is currently unavailable.
# Retrying (1/5) after 1 seconds...
# Uploaded file '0049_jpg.rf.60277a51b0beb8fdd8318fcdfce3d8aa.jpg' as: https://generativelanguage.googleapis.com/v1beta/files
jpg' as: https://generativelanguage.googleapis.com/v1beta/files/540m7gbby43r
# Uploaded file 'geek34_jpg.rf.5e33e068f2a07687be7d1a6df75a28ba.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/540m7gbby43r
#
# Processed image 'geek34_jpg.rf.5e33e068f2a07687be7d1a6df75a28ba.jpg':
# {"prefix": "", "suffix": "{\"amount\": 0.0, \"category\": \"Subscriptions and Memberships\", \"currency\": \"INR\", \"description\": \"Disney Hotstar Mobile 1 year\", \"merchant\": \"Jeeves consumer services Private Limited\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"Credit Card\", \"subcategory\": \"Magazine and Journal Subscriptions\", \"transaction_date\": \"2022-06-15\", \"transaction_id\": \"00125215906545584000\", \"transaction_timestamp\": \"2022-06-15 00:00:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 0.0}", "image": "geek34_jpg.rf.5e33e068f2a07687be7d1a6df75a28ba.jpg"}
#
# Uploaded file 'geek102_jpg.rf.3e0e1fc7625737bbf3241f81bee164f4.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/oy8cfr6jik4e
# Uploaded file 'geek102_jpg.rf.3e0e1fc7625737bbf3241f81bee164f4.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/oy8cfr6jik4e
#
# Processed image 'geek102_jpg.rf.3e0e1fc7625737bbf3241f81bee164f4.jpg':
# {"prefix": "", "suffix": "{\"amount\": 395.0, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"Womens Rayon A-line Printed Long Kurti With Palazzos - M\", \"merchant\": \"Trendy Outfits\", \"original_amount\": 395.0, \"original_currency\": \"INR\", \"transaction_date\": \"2022-03-07\", \"transaction_timestamp\": \"2022-03-07 00:56:10\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "geek102_jpg.rf.3e0e1fc7625737bbf3241f81bee164f4.jpg"}
#
# Uploaded file '14_jpg.rf.cf8c78401769d20033213cd52e51cd8e.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/ghdgu05nyh3f
# Uploaded file '14_jpg.rf.cf8c78401769d20033213cd52e51cd8e.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/ghdgu05nyh3f
#
# Processed image '14_jpg.rf.cf8c78401769d20033213cd52e51cd8e.jpg':
# {"prefix": "", "suffix": "{\"amount\": 201.00, \"category\": \"Food & Drink\", \"subcategory\": \"Restaurant\", \"transaction_date\": \"2021-12-19\", \"transaction_timestamp\": \"2021-12-19 10:05:33\", \"vat_percentage\": 0.05}", "image": "14_jpg.rf.cf8c78401769d20033213cd52e51cd8e.jpg"}
#
# Uploaded file '71_jpeg_jpg.rf.275ebab01bb840270b0711187544a375.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/hy0jxda2kr65
# Uploaded file '71_jpeg_jpg.rf.275ebab01bb840270b0711187544a375.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/hy0jxda2kr65
#
# Processed image '71_jpeg_jpg.rf.275ebab01bb840270b0711187544a375.jpg':
# {"prefix": "", "suffix": "{\"amount\": 403.0, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"GREEN SUPER MART\", \"merchant\": \"GREEN SUPER MART\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"cash\", \"subcategory\": \"Raw Materials\", \"transaction_date\": \"2022-01-29\", \"transaction_id\": \"0041222\", \"transaction_timestamp\": \"2022-01-29 17:20:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "71_jpeg_jpg.rf.275ebab01bb840270b0711187544a375.jpg"}
#
# Uploaded file '17_jpg.rf.142a288444a7ace04c0d7f57cdb498ec.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/suezzqmerl1o
# Uploaded file '17_jpg.rf.142a288444a7ace04c0d7f57cdb498ec.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/suezzqmerl1o
#
# Processed image '17_jpg.rf.142a288444a7ace04c0d7f57cdb498ec.jpg':
# {"prefix": "", "suffix": "{\"amount\": 563.0, \"category\": \"Miscellaneous Expenses\", \"currency\": \"INR\", \"description\": \"GARAM DHARAM\\n(A Unit of Veeru Food Pvt. Ltd.)\\nA Big Fish Venture\\nM-16, Outter Circle, Connaught Place\\nNew Delhi-110001\", \"merchant\": \"GARAM DHARAM\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"Credit Card\", \"subcategory\": \"Meals During Business Travel\", \"transaction_date\": \"2017-02-17\", \"transaction_id\": null, \"transaction_timestamp\": \"2017-02-17 22:53:00\", \"transaction_type\": \"purchase\", \"vat_percentage\": 20.0}", "image": "17_jpg.rf.142a288444a7ace04c0d7f57cdb498ec.jpg"}
#
# Uploaded file '84_png_jpg.rf.63103dfbea7896a44df256670f95d9c5.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/cjdulo1rehzq
# Uploaded file '84_png_jpg.rf.63103dfbea7896a44df256670f95d9c5.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/cjdulo1rehzq
#
# Processed image '84_png_jpg.rf.63103dfbea7896a44df256670f95d9c5.jpg':
# {"prefix": "", "suffix": "{\"amount\": 13715.52, \"category\": \"Marketing and Advertising\", \"currency\": \"INR\", \"description\": \"Frontend design restructure\", \"merchant\": \"Sathon Design\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"Priya Chopra\", \"subcategory\": \"Website Development and Maintenance\", \"transaction_date\": \"2019-01-29\", \"transaction_id\": \"IN-001\", \"transaction_timestamp\": \"2019-01-29 00:00:00\", \"transaction_type\": \"invoice\", \"vat_percentage\": 12.0}", "image": "84_png_jpg.rf.63103dfbea7896a44df256670f95d9c5.jpg"}
#
# Uploaded file '0016_jpg.rf.68c4b9c60819c17aeb817ed2352cc60d.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/htj3xh8ngb15
# Uploaded file '0016_jpg.rf.68c4b9c60819c17aeb817ed2352cc60d.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/htj3xh8ngb15
#
# Processed image '0016_jpg.rf.68c4b9c60819c17aeb817ed2352cc60d.jpg':
# {"prefix": "", "suffix": "{\"amount\": 1486.80, \"category\": \"Marketing and Advertising\", \"currency\": \"USD\", \"description\": \"Invoice INV-17651230 from Carson City Publishers for Random Company\", \"merchant\": \"Carson City Publishers\", \"transaction_date\": \"2022-06-19\", \"transaction_timestamp\": \"2022-06-19 00:00:00\", \"vat_percentage\": 20.0}", "image": "0016_jpg.rf.68c4b9c60819c17aeb817ed2352cc60d.jpg"}
#
# Uploaded file '43_jpeg_jpg.rf.0588dd26b686e518f31f3461fa771102.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/51dq9w9sl4za
# Uploaded file '43_jpeg_jpg.rf.0588dd26b686e518f31f3461fa771102.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/51dq9w9sl4za
#
# Processed image '43_jpeg_jpg.rf.0588dd26b686e518f31f3461fa771102.jpg':
# {"prefix": "", "suffix": "{\"amount\": 680.0, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"Normal\\nChicken\\nRumall\\nShawarma x2\\nChicken\\nMandi x1\", \"merchant\": \"UB Grills and Snacks\", \"original_amount\": 680.0, \"original_currency\": \"INR\", \"transaction_date\": \"2021-12-06\", \"transaction_timestamp\": \"2021-12-06 20:15:00\", \"transaction_type\": \"purchase\", \"vat_percentage\": 20.0}", "image": "43_jpeg_jpg.rf.0588dd26b686e518f31f3461fa771102.jpg"}
#
# Uploaded file '117_jpeg_jpg.rf.05bc9b59d8f7daa7f03b278244447a62.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/xv4klpbpj4jg
# Uploaded file '117_jpeg_jpg.rf.05bc9b59d8f7daa7f03b278244447a62.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/xv4klpbpj4jg
#
# Processed image '117_jpeg_jpg.rf.05bc9b59d8f7daa7f03b278244447a62.jpg':
# {"prefix": "", "suffix": "{\"amount\": 53.0, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"AISHWARYA SUPER MARKET\", \"merchant\": \"AISHWARYA SUPER MARKET\", \"payment_method\": \"Cash\", \"transaction_date\": \"2021-09-22\", \"transaction_timestamp\": \"2021-09-22 02:00:13\", \"vat_percentage\": 20.0}", "image": "117_jpeg_jpg.rf.05bc9b59d8f7daa7f03b278244447a62.jpg"}
#
# Uploaded file '110_jpg.rf.e270a71500e01ef3184ac22ef3d59a66.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/jkbanzau7xnw
# Uploaded file '110_jpg.rf.e270a71500e01ef3184ac22ef3d59a66.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/jkbanzau7xnw
#
# Processed image '110_jpg.rf.e270a71500e01ef3184ac22ef3d59a66.jpg':
# {"prefix": "", "suffix": "{\"amount\": 486.0, \"category\": \"Miscellaneous Expenses\", \"currency\": \"INR\", \"description\": \"KHANDELWAL DHABA\", \"merchant\": \"KHANDELWAL DHABA\", \"original_amount\": 486.0, \"original_currency\": \"INR\", \"payment_method\": \"cash\", \"subcategory\": \"Meals During Business Travel\", \"transaction_date\": \"2077-07-37\", \"transaction_timestamp\": \"2077-07-37 00:00:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "110_jpg.rf.e270a71500e01ef3184ac22ef3d59a66.jpg"}
#
# Uploaded file '97_jpeg_jpg.rf.14445bd2d6ae20804894a39052ba415e.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/xtgy8v31312t
# Uploaded file '97_jpeg_jpg.rf.14445bd2d6ae20804894a39052ba415e.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/xtgy8v31312t
#
# Processed image '97_jpeg_jpg.rf.14445bd2d6ae20804894a39052ba415e.jpg':
# {"prefix": "", "suffix": "{\"amount\": 1534.00, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"BERMUDAS - JOCK, SH - VENFIELD, SH COSMOZONE, SH - GESTURE\", \"merchant\": \"Textile\", \"transaction_date\": \"2015-04-16\", \"transaction_timestamp\": \"2015-04-16 19:32:00\", \"vat_percentage\": 20.0}", "image": "97_jpeg_jpg.rf.14445bd2d6ae20804894a39052ba415e.jpg"}
#
# Uploaded file 'geek46_jpg.rf.234c3560ded04d8446f8a75ddf3b8854.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/pogch283hz7y
# Uploaded file 'geek46_jpg.rf.234c3560ded04d8446f8a75ddf3b8854.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/pogch283hz7y
#
# Processed image 'geek46_jpg.rf.234c3560ded04d8446f8a75ddf3b8854.jpg':
# {"prefix": "", "suffix": "{\"amount\": 599.0, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"TIGYWIGY Women's Satin Printed Top and Pyjama Set Pack of 1\\n(2002 Onion Small) | B08GBKJSBW (2007 Onion_S)\", \"merchant\": \"amazon.in\", \"payment_method\": \"Credit\", \"subcategory\": \"Raw Materials\", \"transaction_date\": \"2022-06-12\", \"transaction_id\": \"404-7039216-8485940\", \"transaction_timestamp\": \"2022-06-12 13:32:14\", \"vat_percentage\": 20.0}", "image": "geek46_jpg.rf.234c3560ded04d8446f8a75ddf3b8854.jpg"}
#
# Uploaded file '68_jpg.rf.41701912a3371e3b7f9c5dc030e0c49b.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/9xzxyrv3drsk
# Uploaded file '68_jpg.rf.41701912a3371e3b7f9c5dc030e0c49b.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/9xzxyrv3drsk
#
# Processed image '68_jpg.rf.41701912a3371e3b7f9c5dc030e0c49b.jpg':
# {"prefix": "", "suffix": "{\"amount\": 75, \"category\": \"Food & Drink\", \"subcategory\": \"Restaurant\", \"transaction_date\": \"2017-08-19\", \"transaction_timestamp\": \"2017-08-19 09:15:00\", \"vat_percentage\": 0.00}", "image": "68_jpg.rf.41701912a3371e3b7f9c5dc030e0c49b.jpg"}
#
# Error processing image 'geek98_jpg.rf.02704d053cbfb7ad12ffdd730531d337.jpg': 503 The service is currently unavailable.
# Retrying (1/5) after 1 seconds...
# Uploaded file 'geek98_jpg.rf.02704d053cbfb7ad12ffdd730531d337.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/usxagotyzwol
# Uploaded file 'geek98_jpg.rf.02704d053cbfb7ad12ffdd730531d337.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/usxagotyzwol
#
# Processed image 'geek98_jpg.rf.02704d053cbfb7ad12ffdd730531d337.jpg':
# {"prefix": "", "suffix": "{\"amount\": 650.0, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"Trendy Alluring Women Kurta\", \"merchant\": \"Trendy Outfits\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"Credit Card\", \"subcategory\": \"Raw Materials\", \"transaction_date\": \"2022-03-27\", \"transaction_id\": \"98wvr2213672\", \"transaction_timestamp\": \"2022-03-27 16:06:24\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "geek98_jpg.rf.02704d053cbfb7ad12ffdd730531d337.jpg"}
#
# Error processing image '000_jpg.rf.f73520828c17aee8f9dfd2b92895b5e8.jpg': 503 The service is currently unavailable.
# Retrying (1/5) after 1 seconds...
# Uploaded file '000_jpg.rf.f73520828c17aee8f9dfd2b92895b5e8.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/nbonwx1k8c5o
# Uploaded file '000_jpg.rf.f73520828c17aee8f9dfd2b92895b5e8.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/nbonwx1k8c5o
# Error processing image '000_jpg.rf.f73520828c17aee8f9dfd2b92895b5e8.jpg': 504 Deadline Exceeded
# Retrying (2/5) after 3 seconds...
# Error processing image '000_jpg.rf.f73520828c17aee8f9dfd2b92895b5e8.jpg': 503 recvmsg:Connection reset by peer
# Retrying (3/5) after 5 seconds...
# ...
#
# Uploaded file '29_png_jpg.rf.d670c199241a3cb2ca10f214b161261f.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/be832ubur687
# Uploaded file '29_png_jpg.rf.d670c199241a3cb2ca10f214b161261f.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/be832ubur687
#
# Processed image '29_png_jpg.rf.d670c199241a3cb2ca10f214b161261f.jpg':
# {"prefix": "", "suffix": "{\"transaction_date\": \"2022-07-02\", \"transaction_timestamp\": \"2022-07-02 00:00:00\", \"transaction_type\": \"Restaurant\", \"vat_percentage\": 5.0}", "image": "29_png_jpg.rf.d670c199241a3cb2ca10f214b161261f.jpg"}
#
# Uploaded file '57_png_jpg.rf.805796958c0bbe5817198366ba38ddf3.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/drwb6b9dwwdg
# Uploaded file '57_png_jpg.rf.805796958c0bbe5817198366ba38ddf3.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/drwb6b9dwwdg
#
# Processed image '57_png_jpg.rf.805796958c0bbe5817198366ba38ddf3.jpg':
# {"prefix": "", "suffix": "{\"amount\": 16325.00, \"category\": \"Travel and Transportation\", \"currency\": \"INR\", \"description\": \"NOVOTEL Artsity Bar\", \"merchant\": \"NOVOTEL\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"Dine In\", \"subcategory\": \"Meals During Business Travel\", \"transaction_date\": \"2022-05-20\", \"transaction_id\": \"2-402-16780\", \"transaction_timestamp\": \"2022-05-20 02:13:20\", \"transaction_type\": \"purchase\", \"vat_percentage\": 0.0}", "image": "57_png_jpg.rf.805796958c0bbe5817198366ba38ddf3.jpg"}
#
# Uploaded file '0032_jpg.rf.d9b65e245f163c6408f6606f6b15f7bc.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/xzx88r5dkwht
# Uploaded file '0032_jpg.rf.d9b65e245f163c6408f6606f6b15f7bc.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/xzx88r5dkwht
#
# Processed image '0032_jpg.rf.d9b65e245f163c6408f6606f6b15f7bc.jpg':
# {"prefix": "", "suffix": "{\"amount\": 944.00, \"category\": \"Professional Services\", \"currency\": \"GBP\", \"description\": \"Invoice #2409088 for Supporting of in-house project (hours worked)\", \"merchant\": \"Crane Pool & Schmidt Pte Ltd\", \"payment_method\": \"PO\", \"subcategory\": \"Consulting Fees\", \"transaction_date\": \"2022-06-26\", \"transaction_id\": \"456001200\", \"transaction_timestamp\": \"2022-06-26 00:00:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "0032_jpg.rf.d9b65e245f163c6408f6606f6b15f7bc.jpg"}
#
# Uploaded file '95_jpeg_jpg.rf.31f3278a999ce75150fc65fcce975847.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/p6rb5f911scz
# Uploaded file '95_jpeg_jpg.rf.31f3278a999ce75150fc65fcce975847.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/p6rb5f911scz
#
# Processed image '95_jpeg_jpg.rf.31f3278a999ce75150fc65fcce975847.jpg':
# {"prefix": "", "suffix": "{\"amount\": 1682.01, \"category\": \"Cost of Goods Sold\", \"currency\": \"GBP\", \"description\": \"Abdullah Pharma\", \"merchant\": \"Abdullah Pharma\", \"transaction_date\": \"2020-09-03\", \"transaction_timestamp\": \"2020-09-03 06:05:12\", \"vat_percentage\": 20.0}", "image": "95_jpeg_jpg.rf.31f3278a999ce75150fc65fcce975847.jpg"}
#
# Uploaded file 'geek73_jpg.rf.7ba2f89a3496605dc543df674acbb090.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/got3sa71g5ix
# Uploaded file 'geek73_jpg.rf.7ba2f89a3496605dc543df674acbb090.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/got3sa71g5ix
#
# Processed image 'geek73_jpg.rf.7ba2f89a3496605dc543df674acbb090.jpg':
# {"prefix": "", "suffix": "{\"amount\": 475.00, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"Nykaa\", \"merchant\": \"Nykaa\", \"transaction_date\": \"2023-07-26\", \"transaction_timestamp\": \"2023-07-26 00:00:00\", \"vat_percentage\": 20.0}", "image": "geek73_jpg.rf.7ba2f89a3496605dc543df674acbb090.jpg"}
#
# Uploaded file '89_jpeg_jpg.rf.da566609cfaa0b23fb9a22ab72b79b74.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/dv17k92pbet0
# Uploaded file '89_jpeg_jpg.rf.da566609cfaa0b23fb9a22ab72b79b74.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/dv17k92pbet0
#
# Processed image '89_jpeg_jpg.rf.da566609cfaa0b23fb9a22ab72b79b74.jpg':
# {"prefix": "", "suffix": "{\"amount\": 309.0, \"category\": \"Miscellaneous Expenses\", \"currency\": \"INR\", \"description\": \"SHREE PANCHAVATI MEGA MART\", \"merchant\": \"SHREE PANCHAVATI MEGA MART\", \"payment_method\": \"CASH\", \"transaction_date\": \"2022-01-19\", \"transaction_timestamp\": \"2022-01-19 06:27:04\", \"vat_percentage\": 20.0}", "image": "89_jpeg_jpg.rf.da566609cfaa0b23fb9a22ab72b79b74.jpg"}
#
# Uploaded file 'geek1_jpg.rf.cdadc1dbc0e535254adefe783102b976.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/2d69fky55tvs
# Uploaded file 'geek1_jpg.rf.cdadc1dbc0e535254adefe783102b976.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/2d69fky55tvs
#
# Processed image 'geek1_jpg.rf.cdadc1dbc0e535254adefe783102b976.jpg':
# {"prefix": "", "suffix": "{\"amount\": 449.0, \"category\": \"Miscellaneous Expenses\", \"currency\": \"INR\", \"description\": \"WILDHORNS Carter Leather Wallet for Men (Blue Hunter)\", \"merchant\": \"Cloudtail India Private Limited\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"Credit Card\", \"subcategory\": \"Promotional Items\", \"transaction_date\": \"2021-08-14\", \"transaction_id\": \"171-8704907-5550741\", \"transaction_timestamp\": \"2021-08-14 12:55:39\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 18.0}", "image": "geek1_jpg.rf.cdadc1dbc0e535254adefe783102b976.jpg"}
#
# Uploaded file 'geek10_jpg.rf.5db84e441c5db249f88c228b8afa59b7.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/hqai22fy6zn0
# Uploaded file 'geek10_jpg.rf.5db84e441c5db249f88c228b8afa59b7.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/hqai22fy6zn0
#
# Processed image 'geek10_jpg.rf.5db84e441c5db249f88c228b8afa59b7.jpg':
# {"prefix": "", "suffix": "{\"amount\": 178.00, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"Dupatta set\", \"merchant\": \"Trendy Outfits\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"card\", \"subcategory\": \"Raw Materials\", \"transaction_date\": \"2022-08-31\", \"transaction_id\": \"1238874\", \"transaction_timestamp\": \"2022-08-31 10:15:48\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "geek10_jpg.rf.5db84e441c5db249f88c228b8afa59b7.jpg"}
#
# Uploaded file '91_jpg.rf.891e9d49d674933cfc797ffa2ff147a2.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/7v65eopguq05
# Uploaded file '91_jpg.rf.891e9d49d674933cfc797ffa2ff147a2.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/7v65eopguq05
#
# Processed image '91_jpg.rf.891e9d49d674933cfc797ffa2ff147a2.jpg':
# {"prefix": "", "suffix": "{\"amount\": 494.55, \"category\": \"Miscellaneous Expenses\", \"currency\": \"INR\", \"description\": \"Jubilant FoodWorks Limited\", \"merchant\": \"Dominos\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"PAYTM\", \"subcategory\": \"Meals During Business Travel\", \"transaction_date\": \"2022-02-26\", \"transaction_id\": \"67178/21/56132\", \"transaction_timestamp\": \"2022-02-26 18:15:00\", \"transaction_type\": \"purchase\", \"vat_percentage\": 20.0}", "image": "91_jpg.rf.891e9d49d674933cfc797ffa2ff147a2.jpg"}
#
# Uploaded file 'geek4_jpg.rf.75d83d1dbe0de064754b6f84e1f772b6.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/iwpfngbjuqbe
# Uploaded file 'geek4_jpg.rf.75d83d1dbe0de064754b6f84e1f772b6.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/iwpfngbjuqbe
#
# Processed image 'geek4_jpg.rf.75d83d1dbe0de064754b6f84e1f772b6.jpg':
# {"prefix": "", "suffix": "{\"amount\": 670.00, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"KURTI-L\", \"merchant\": \"Trenity Outfit\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"Credit Card\", \"subcategory\": \"Raw Materials\", \"transaction_date\": \"2022-06-20\", \"transaction_id\": \"lu2k234868\", \"transaction_timestamp\": \"2022-06-20 11:32:21\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "geek4_jpg.rf.75d83d1dbe0de064754b6f84e1f772b6.jpg"}
#
# Uploaded file '0034_jpg.rf.22c63d825ca5ab352b92561d36ce677d.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/bqtxxuorh5vh
# Uploaded file '0034_jpg.rf.22c63d825ca5ab352b92561d36ce677d.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/bqtxxuorh5vh
#
# Processed image '0034_jpg.rf.22c63d825ca5ab352b92561d36ce677d.jpg':
# {"prefix": "", "suffix": "{\"amount\": 888.00, \"category\": \"Professional Services\", \"currency\": \"USD\", \"description\": \"Consulting Fees\", \"merchant\": \"Crane Pool & Schmidt Pte Ltd\", \"transaction_date\": \"2022-06-17\", \"transaction_timestamp\": \"2022-06-17 00:00:00\", \"vat_percentage\": 20.0}", "image": "0034_jpg.rf.22c63d825ca5ab352b92561d36ce677d.jpg"}
#
# Uploaded file '125_jpg.rf.468fc881773b0ed489f674a53a745f86.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/gtweb1iac8z3
# Uploaded file '125_jpg.rf.468fc881773b0ed489f674a53a745f86.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/gtweb1iac8z3
#
# Processed image '125_jpg.rf.468fc881773b0ed489f674a53a745f86.jpg':
# {"prefix": "", "suffix": "{\"amount\": 472.0, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"Pizza Hut\", \"merchant\": \"Pizza Hut\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"cash\", \"subcategory\": \"Raw Materials\", \"transaction_date\": \"2016-04-08\", \"transaction_id\": null, \"transaction_timestamp\": \"2016-04-08 13:38:20\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "125_jpg.rf.468fc881773b0ed489f674a53a745f86.jpg"}
#
# Uploaded file '28_jpg.rf.790958435f163b15f4ca95f3d735c9b8.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/7se1sajrxb49
# Uploaded file '28_jpg.rf.790958435f163b15f4ca95f3d735c9b8.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/7se1sajrxb49
#
# Processed image '28_jpg.rf.790958435f163b15f4ca95f3d735c9b8.jpg':
# {"prefix": "", "suffix": "{\"amount\": 452.0, \"category\": \"Cost of Goods Sold\", \"currency\": \"INR\", \"description\": \"AISHWARYA SUPER MARKET\", \"merchant\": \"AISHWARYA SUPER MARKET\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"Cash\", \"subcategory\": \"Raw Materials\", \"transaction_date\": \"2022-06-03\", \"transaction_id\": \"INV-ASM17986\", \"transaction_timestamp\": \"2022-06-03 12:01:44\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "28_jpg.rf.790958435f163b15f4ca95f3d735c9b8.jpg"}
#
# Uploaded file '0014_jpg.rf.ece623fbda67880536b0c4b9fb835247.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/tc1rawhqb0l6
# Uploaded file '0014_jpg.rf.ece623fbda67880536b0c4b9fb835247.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/tc1rawhqb0l6
#
# Processed image '0014_jpg.rf.ece623fbda67880536b0c4b9fb835247.jpg':
# {"prefix": "", "suffix": "{\"amount\": 863.17, \"category\": \"Office and Administrative\", \"currency\": \"USD\", \"description\": \"Balance Due\", \"merchant\": \"Crane Pool & Schmidt Pte Ltd\", \"transaction_date\": \"2022-04-13\", \"transaction_timestamp\": \"2022-04-13 00:00:00\", \"vat_percentage\": 20.0}", "image": "0014_jpg.rf.ece623fbda67880536b0c4b9fb835247.jpg"}
#
# Uploaded file '0033_jpg.rf.c61dfebd1c1e891db74f7ba1b305dd86.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/3zj8su470ple
# Uploaded file '0033_jpg.rf.c61dfebd1c1e891db74f7ba1b305dd86.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/3zj8su470ple
#
# Processed image '0033_jpg.rf.c61dfebd1c1e891db74f7ba1b305dd86.jpg':
# {"prefix": "", "suffix": "{\"amount\": 821.9, \"category\": \"Professional Services\", \"currency\": \"USD\", \"description\": \"Supporting of in-house project\", \"merchant\": \"Crane Pool & Schmidt Pte Ltd\", \"payment_method\": \"invoice\", \"subcategory\": \"Consulting Fees\", \"transaction_date\": \"2022-06-11\", \"transaction_id\": \"250158\", \"transaction_timestamp\": \"2022-06-11 00:00:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "0033_jpg.rf.c61dfebd1c1e891db74f7ba1b305dd86.jpg"}
#
# Uploaded file 'geek19_jpg.rf.d2105e2fb2128d5e7fa157394ea83571.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/bje2x2pps163
# Uploaded file 'geek19_jpg.rf.d2105e2fb2128d5e7fa157394ea83571.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/bje2x2pps163
#
# Processed image 'geek19_jpg.rf.d2105e2fb2128d5e7fa157394ea83571.jpg':
# {"prefix": "", "suffix": "{\"amount\": 1499.0, \"category\": \"Subscriptions and Memberships\", \"currency\": \"INR\", \"description\": \"Amazon Prime (Yearly Membership)\", \"merchant\": \"Amazon Seller Services Private Limited\", \"payment_method\": \"Credit Card\", \"subcategory\": \"Magazine and Journal Subscriptions\", \"transaction_date\": \"2022-04-02\", \"transaction_id\": \"3eROAzr166L2Kho03\", \"transaction_timestamp\": \"2022-04-02 14:21:52\", \"vat_percentage\": 0.0}", "image": "geek19_jpg.rf.d2105e2fb2128d5e7fa157394ea83571.jpg"}
#
# Uploaded file '84_png_jpg.rf.be32c429cc03e97ac4825a4eb9fecc08.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/p2yb2y03x979
# Uploaded file '84_png_jpg.rf.be32c429cc03e97ac4825a4eb9fecc08.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/p2yb2y03x979
#
# Processed image '84_png_jpg.rf.be32c429cc03e97ac4825a4eb9fecc08.jpg':
# {"prefix": "", "suffix": "{\"amount\": 13715.52, \"category\": \"Marketing and Advertising\", \"currency\": \"INR\", \"description\": \"Saffron Design\", \"merchant\": \"Saffron Design\", \"transaction_date\": \"2019-01-29\", \"transaction_timestamp\": \"2019-01-29 00:00:00\", \"vat_percentage\": 20.0}", "image": "84_png_jpg.rf.be32c429cc03e97ac4825a4eb9fecc08.jpg"}
#
# Uploaded file 'F_jpg.rf.2b9fe8a9817c57061cde19e66bf2fdcc.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/alawg4uem6wr
# Uploaded file 'F_jpg.rf.2b9fe8a9817c57061cde19e66bf2fdcc.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/alawg4uem6wr
#
# Processed image 'F_jpg.rf.2b9fe8a9817c57061cde19e66bf2fdcc.jpg':
# {"prefix": "", "suffix": "{\"amount\": 88000.00, \"category\": \"Office and Administrative\", \"currency\": \"INR\", \"description\": \"Royal Electric Store\", \"merchant\": \"Royal Electric Store\", \"transaction_date\": \"2020-06-14\", \"transaction_timestamp\": \"2020-06-14 00:00:00\", \"transaction_type\": \"Purchase\", \"vat_percentage\": 20.0}", "image": "F_jpg.rf.2b9fe8a9817c57061cde19e66bf2fdcc.jpg"}
#
# Uploaded file '103_jpg.rf.a012ebc7fb21d6ed5b9673b95858896d.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/5fm19r9luxr0
# Uploaded file '103_jpg.rf.a012ebc7fb21d6ed5b9673b95858896d.jpg' as: https://generativelanguage.googleapis.com/v1beta/files/5fm19r9luxr0
#
# Processed image '103_jpg.rf.a012ebc7fb21d6ed5b9673b95858896d.jpg':
# {"prefix": "", "suffix": "{\"amount\": 7771.0, \"category\": \"Miscellaneous Expenses\", \"currency\": \"INR\", \"description\": \"lanterns kitchen & bar\\n164, D.D.A Complex Rajendra Bhawan\\nRajendra Place, New Delhi-110008\\nTel: 25826257, 41538955\\nEma11:contact@lanternsdelhi.com\", \"merchant\": \"lanterns kitchen & bar\", \"original_amount\": null, \"original_currency\": null, \"payment_method\": \"Credit Card\", \"subcategory\": \"Staff Entertainment\", \"transaction_date\": \"2016-06-04\", \"transaction_id\": null, \"transaction_timestamp\": \"2016-06-04 23:21:00\", \"transaction_type\": \"purchase\", \"vat_percentage\": 20.0}", "image": "103_jpg.rf.a012ebc7fb21d6ed5b9673b95858896d.jpg"}
